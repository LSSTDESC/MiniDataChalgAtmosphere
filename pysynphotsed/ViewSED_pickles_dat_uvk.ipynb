# %% [markdown]
# # The purpose is to show the Pickles UVK

# %% [markdown]
# ## Definitions of the libraries

# %%
import numpy as np
# Set up matplotlib and use a nicer set of plot parameters
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import astropy
from astropy.io import fits
from astropy.coordinates import SkyCoord, EarthLocation, AltAz

# %%
import pandas as pd
import os
import re

# %%
from astroquery.simbad import Simbad

# %%
# to enlarge the sizes
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 8),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
top_pysynphot_data_dir=os.environ['PYSYN_CDBS']

# %%
import pysynphot as S
S.primary_area=6*1e4
S.binning=10.

# %% [markdown]
# ## Defines where are the data

# %%
dir_star='calspec'
dir_nostar='grid'

# %%
dir_submodels=['agn','bpgs','extinction','jacobi','phoenix','bc95','bz77','galactic',\
               'k93models','pickles','bkmodels','ck04models','gunnstryker','kc96']

# %% [markdown]
# ## where are the files

# %%
SEDfile_dir=os.path.join(top_pysynphot_data_dir,dir_nostar,dir_submodels[9],'dat_uvk')

# %%
filelist=os.listdir(SEDfile_dir)

# %%
fits_files = [f for f in os.listdir(SEDfile_dir) if f.endswith('.fits')]

# %%
fits_files
# Out:
# ['pickles_uk_53.fits',
#  'pickles_uk_12.fits',
#  'pickles_uk_124.fits',
#  'pickles_uk_6.fits',
#  'pickles_uk_45.fits',
#  'pickles_uk_108.fits',
#  'pickles_uk_86.fits',
#  'pickles_uk_69.fits',
#  'pickles_uk_90.fits',
#  'pickles_uk_28.fits',
#  'pickles_uk_128.fits',
#  'pickles_uk_49.fits',
#  'pickles_uk_104.fits',
#  'pickles_uk_32.fits',
#  'pickles_uk_65.fits',
#  'pickles_uk_73.fits',
#  'pickles_uk_112.fits',
#  'pickles_uk_24.fits',
#  'pickles_uk_113.fits',
#  'pickles_uk_25.fits',
#  'pickles_uk_72.fits',
#  'pickles_uk_64.fits',
#  'pickles_uk_105.fits',
#  'pickles_uk_33.fits',
#  'pickles_uk_48.fits',
#  'pickles_uk_129.fits',
#  'pickles_uk_29.fits',
#  'pickles_uk_91.fits',
#  'pickles_uk_87.fits',
#  'pickles_uk_68.fits',
#  'pickles_uk_109.fits',
#  'pickles_uk_44.fits',
#  'pickles_uk_7.fits',
#  'pickles_uk_13.fits',
#  'pickles_uk_125.fits',
#  'pickles_uk_52.fits',
#  'pickles_uk_59.fits',
#  'pickles_uk_18.fits',
#  'pickles_uk_102.fits',
#  'pickles_uk_34.fits',
#  'pickles_uk_63.fits',
#  'pickles_uk_75.fits',
#  'pickles_uk_114.fits',
#  'pickles_uk_22.fits',
#  'pickles_uk_55.fits',
#  'pickles_uk_14.fits',
#  'pickles_uk_122.fits',
#  'pickles_uk_43.fits',
#  'pickles_uk_38.fits',
#  'pickles_uk_80.fits',
#  'pickles_uk_96.fits',
#  'pickles_uk_79.fits',
#  'pickles_uk_118.fits',
#  'pickles_uk_119.fits',
#  'pickles_uk_97.fits',
#  'pickles_uk_78.fits',
#  'pickles_uk_81.fits',
#  'pickles_uk_39.fits',
#  'pickles_uk_42.fits',
#  'pickles_uk_1.fits',
#  'pickles_uk_15.fits',
#  'pickles_uk_123.fits',
#  'pickles_uk_54.fits',
#  'pickles_uk_115.fits',
#  'pickles_uk_23.fits',
#  'pickles_uk_74.fits',
#  'pickles_uk_62.fits',
#  'pickles_uk_103.fits',
#  'pickles_uk_35.fits',
#  'pickles_uk_19.fits',
#  'pickles_uk_58.fits',
#  'pickles_uk_20.fits',
#  'pickles_uk_116.fits',
#  'pickles_uk_77.fits',
#  'pickles_uk_98.fits',
#  'pickles_uk_61.fits',
#  'pickles_uk_36.fits',
#  'pickles_uk_100.fits',
#  'pickles_uk_94.fits',
#  'pickles_uk_82.fits',
#  'pickles_uk_41.fits',
#  'pickles_uk_2.fits',
#  'pickles_uk_120.fits',
#  'pickles_uk_16.fits',
#  'pickles_uk_57.fits',
#  'pickles_uk_56.fits',
#  'pickles_uk_121.fits',
#  'pickles_uk_17.fits',
#  'pickles_uk_3.fits',
#  'pickles_uk_40.fits',
#  'pickles_uk_83.fits',
#  'pickles_uk_95.fits',
#  'pickles_uk_37.fits',
#  'pickles_uk_101.fits',
#  'pickles_uk_60.fits',
#  'pickles_uk_76.fits',
#  'pickles_uk_99.fits',
#  'pickles_uk_21.fits',
#  'pickles_uk_117.fits',
#  'pickles_uk_92.fits',
#  'pickles_uk_84.fits',
#  'pickles_uk_47.fits',
#  'pickles_uk_4.fits',
#  'pickles_uk_126.fits',
#  'pickles_uk_10.fits',
#  'pickles_uk_130.fits',
#  'pickles_uk_51.fits',
#  'pickles_uk_26.fits',
#  'pickles_uk_110.fits',
#  'pickles_uk_71.fits',
#  'pickles_uk_67.fits',
#  'pickles_uk_88.fits',
#  'pickles_uk_30.fits',
#  'pickles_uk_106.fits',
#  'pickles_uk_8.fits',
#  'pickles_uk_9.fits',
#  'pickles_uk.fits',
#  'pickles_uk_31.fits',
#  'pickles_uk_107.fits',
#  'pickles_uk_66.fits',
#  'pickles_uk_89.fits',
#  'pickles_uk_70.fits',
#  'pickles_uk_27.fits',
#  'pickles_uk_111.fits',
#  'pickles_uk_50.fits',
#  'pickles_uk_131.fits',
#  'pickles_uk_127.fits',
#  'pickles_uk_11.fits',
#  'pickles_uk_5.fits',
#  'pickles_uk_46.fits',
#  'pickles_uk_85.fits',
#  'pickles_uk_93.fits']

# %%
fits_files.remove('pickles_uk.fits')

# %% [markdown]
# ## Find the star-names in the files

# %%
obj_headers = []
obj_files = []
for filename in fits_files:
    index=0
    if re.search('fits',filename):  #example of filename filter
        index+=1
        fullfilename = os.path.join(SEDfile_dir,filename)
        hdr = fits.getheader(fullfilename)
        obj_headers.append(hdr)
        obj_files.append(filename)

# %%
obj_headers[0]
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                   16 / Bits per pixel
# NAXIS   =                    0 / Number of axes
# EXTEND  =                    T / File may contain extensions
# DATE    = '2007-01-11T21:02:21' / Date FITS file was generated
# IRAF-TLM= '16:02:37 (11/01/2007)' / Time of last modification
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# ORIGIN  = 'STScI-STSDAS/TABLES' / Tables version 2002-02-22
# FILENAME= 'pickles_uk_53.fits' / name of file
# NEXTEND =                    1 / number of extensions in file
# COMMENT1= 'spectral type: G0IV'
# COMMENT2= 'metallicity: solar'
# COMMENT3= 'original filename: ukg0iv.dat'
# HISTORY   File created by F.R.Boffi.
# HISTORY   SEDs from Pickles UVKLIB Library (1998, PASP 110, 863).
# HISTORY   Wavelength is in Angstrom.
# HISTORY   Fluxes are tabulated in units of erg/s/cm^2/A
# HISTORY   and were calculated by normalizing the original fluxes
# HISTORY   in the Pickles V band to a 0 magnitude in vegamag.
# HISTORY   In the vegamag system, Vega has magnitude zero in all passbands.
# HISTORY   Please refer to the SYNPHOT manual for further information.

# %%
#obj_names = []
#index=0
#for hdr in obj_headers: 
#        obj_name=obj_headers[index]['TARGETID']
#        obj_names.append(obj_name)
#        index+=1

# %%
#obj_names

# %%
fits_files[:5]
# Out:
# ['pickles_uk_53.fits',
#  'pickles_uk_12.fits',
#  'pickles_uk_124.fits',
#  'pickles_uk_6.fits',
#  'pickles_uk_45.fits']

# %%
obj_names2 = []
index=0
for thefile in fits_files:
    #thenames=re.findall('^bk_([a-z][0-9]+).fits$',thefile)
    thenames=re.findall('^(.*).fits$',thefile) 
    if(len(thenames)>0):
        obj_names2.append(thenames[0])
    else:
        print 'bad file ',thefile
    index+=1

# %%
print obj_names2
# Out:
# ['pickles_uk_53', 'pickles_uk_12', 'pickles_uk_124', 'pickles_uk_6', 'pickles_uk_45', 'pickles_uk_108', 'pickles_uk_86', 'pickles_uk_69', 'pickles_uk_90', 'pickles_uk_28', 'pickles_uk_128', 'pickles_uk_49', 'pickles_uk_104', 'pickles_uk_32', 'pickles_uk_65', 'pickles_uk_73', 'pickles_uk_112', 'pickles_uk_24', 'pickles_uk_113', 'pickles_uk_25', 'pickles_uk_72', 'pickles_uk_64', 'pickles_uk_105', 'pickles_uk_33', 'pickles_uk_48', 'pickles_uk_129', 'pickles_uk_29', 'pickles_uk_91', 'pickles_uk_87', 'pickles_uk_68', 'pickles_uk_109', 'pickles_uk_44', 'pickles_uk_7', 'pickles_uk_13', 'pickles_uk_125', 'pickles_uk_52', 'pickles_uk_59', 'pickles_uk_18', 'pickles_uk_102', 'pickles_uk_34', 'pickles_uk_63', 'pickles_uk_75', 'pickles_uk_114', 'pickles_uk_22', 'pickles_uk_55', 'pickles_uk_14', 'pickles_uk_122', 'pickles_uk_43', 'pickles_uk_38', 'pickles_uk_80', 'pickles_uk_96', 'pickles_uk_79', 'pickles_uk_118', 'pickles_uk_119', 'pickles_uk_97', 'pickles_uk_78', 'pickles_uk_81', 'pickles_uk_39', 'pickles_uk_42', 'pickles_uk_1', 'pickles_uk_15', 'pickles_uk_123', 'pickles_uk_54', 'pickles_uk_115', 'pickles_uk_23', 'pickles_uk_74', 'pickles_uk_62', 'pickles_uk_103', 'pickles_uk_35', 'pickles_uk_19', 'pickles_uk_58', 'pickles_uk_20', 'pickles_uk_116', 'pickles_uk_77', 'pickles_uk_98', 'pickles_uk_61', 'pickles_uk_36', 'pickles_uk_100', 'pickles_uk_94', 'pickles_uk_82', 'pickles_uk_41', 'pickles_uk_2', 'pickles_uk_120', 'pickles_uk_16', 'pickles_uk_57', 'pickles_uk_56', 'pickles_uk_121', 'pickles_uk_17', 'pickles_uk_3', 'pickles_uk_40', 'pickles_uk_83', 'pickles_uk_95', 'pickles_uk_37', 'pickles_uk_101', 'pickles_uk_60', 'pickles_uk_76', 'pickles_uk_99', 'pickles_uk_21', 'pickles_uk_117', 'pickles_uk_92', 'pickles_uk_84', 'pickles_uk_47', 'pickles_uk_4', 'pickles_uk_126', 'pickles_uk_10', 'pickles_uk_130', 'pickles_uk_51', 'pickles_uk_26', 'pickles_uk_110', 'pickles_uk_71', 'pickles_uk_67', 'pickles_uk_88', 'pickles_uk_30', 'pickles_uk_106', 'pickles_uk_8', 'pickles_uk_9', 'pickles_uk_31', 'pickles_uk_107', 'pickles_uk_66', 'pickles_uk_89', 'pickles_uk_70', 'pickles_uk_27', 'pickles_uk_111', 'pickles_uk_50', 'pickles_uk_131', 'pickles_uk_127', 'pickles_uk_11', 'pickles_uk_5', 'pickles_uk_46', 'pickles_uk_85', 'pickles_uk_93']

# %%
obj_names=obj_names2

# %%
print obj_files
# Out:
# ['pickles_uk_53.fits', 'pickles_uk_12.fits', 'pickles_uk_124.fits', 'pickles_uk_6.fits', 'pickles_uk_45.fits', 'pickles_uk_108.fits', 'pickles_uk_86.fits', 'pickles_uk_69.fits', 'pickles_uk_90.fits', 'pickles_uk_28.fits', 'pickles_uk_128.fits', 'pickles_uk_49.fits', 'pickles_uk_104.fits', 'pickles_uk_32.fits', 'pickles_uk_65.fits', 'pickles_uk_73.fits', 'pickles_uk_112.fits', 'pickles_uk_24.fits', 'pickles_uk_113.fits', 'pickles_uk_25.fits', 'pickles_uk_72.fits', 'pickles_uk_64.fits', 'pickles_uk_105.fits', 'pickles_uk_33.fits', 'pickles_uk_48.fits', 'pickles_uk_129.fits', 'pickles_uk_29.fits', 'pickles_uk_91.fits', 'pickles_uk_87.fits', 'pickles_uk_68.fits', 'pickles_uk_109.fits', 'pickles_uk_44.fits', 'pickles_uk_7.fits', 'pickles_uk_13.fits', 'pickles_uk_125.fits', 'pickles_uk_52.fits', 'pickles_uk_59.fits', 'pickles_uk_18.fits', 'pickles_uk_102.fits', 'pickles_uk_34.fits', 'pickles_uk_63.fits', 'pickles_uk_75.fits', 'pickles_uk_114.fits', 'pickles_uk_22.fits', 'pickles_uk_55.fits', 'pickles_uk_14.fits', 'pickles_uk_122.fits', 'pickles_uk_43.fits', 'pickles_uk_38.fits', 'pickles_uk_80.fits', 'pickles_uk_96.fits', 'pickles_uk_79.fits', 'pickles_uk_118.fits', 'pickles_uk_119.fits', 'pickles_uk_97.fits', 'pickles_uk_78.fits', 'pickles_uk_81.fits', 'pickles_uk_39.fits', 'pickles_uk_42.fits', 'pickles_uk_1.fits', 'pickles_uk_15.fits', 'pickles_uk_123.fits', 'pickles_uk_54.fits', 'pickles_uk_115.fits', 'pickles_uk_23.fits', 'pickles_uk_74.fits', 'pickles_uk_62.fits', 'pickles_uk_103.fits', 'pickles_uk_35.fits', 'pickles_uk_19.fits', 'pickles_uk_58.fits', 'pickles_uk_20.fits', 'pickles_uk_116.fits', 'pickles_uk_77.fits', 'pickles_uk_98.fits', 'pickles_uk_61.fits', 'pickles_uk_36.fits', 'pickles_uk_100.fits', 'pickles_uk_94.fits', 'pickles_uk_82.fits', 'pickles_uk_41.fits', 'pickles_uk_2.fits', 'pickles_uk_120.fits', 'pickles_uk_16.fits', 'pickles_uk_57.fits', 'pickles_uk_56.fits', 'pickles_uk_121.fits', 'pickles_uk_17.fits', 'pickles_uk_3.fits', 'pickles_uk_40.fits', 'pickles_uk_83.fits', 'pickles_uk_95.fits', 'pickles_uk_37.fits', 'pickles_uk_101.fits', 'pickles_uk_60.fits', 'pickles_uk_76.fits', 'pickles_uk_99.fits', 'pickles_uk_21.fits', 'pickles_uk_117.fits', 'pickles_uk_92.fits', 'pickles_uk_84.fits', 'pickles_uk_47.fits', 'pickles_uk_4.fits', 'pickles_uk_126.fits', 'pickles_uk_10.fits', 'pickles_uk_130.fits', 'pickles_uk_51.fits', 'pickles_uk_26.fits', 'pickles_uk_110.fits', 'pickles_uk_71.fits', 'pickles_uk_67.fits', 'pickles_uk_88.fits', 'pickles_uk_30.fits', 'pickles_uk_106.fits', 'pickles_uk_8.fits', 'pickles_uk_9.fits', 'pickles_uk_31.fits', 'pickles_uk_107.fits', 'pickles_uk_66.fits', 'pickles_uk_89.fits', 'pickles_uk_70.fits', 'pickles_uk_27.fits', 'pickles_uk_111.fits', 'pickles_uk_50.fits', 'pickles_uk_131.fits', 'pickles_uk_127.fits', 'pickles_uk_11.fits', 'pickles_uk_5.fits', 'pickles_uk_46.fits', 'pickles_uk_85.fits', 'pickles_uk_93.fits']

# %%
objames_and_objfiles = zip(obj_names, obj_files)

# %% [markdown]
# ## Make a dictionary of filenames

# %%
OBJDict= {}
for obj,thefile in objames_and_objfiles:
    print obj,': '
    OBJDict[obj]=thefile
    print OBJDict[obj]
# Out:
# pickles_uk_53 :
# pickles_uk_53.fits
# pickles_uk_12 :
# pickles_uk_12.fits
# pickles_uk_124 :
# pickles_uk_124.fits
# pickles_uk_6 :
# pickles_uk_6.fits
# pickles_uk_45 :
# pickles_uk_45.fits
# pickles_uk_108 :
# pickles_uk_108.fits
# pickles_uk_86 :
# pickles_uk_86.fits
# pickles_uk_69 :
# pickles_uk_69.fits
# pickles_uk_90 :
# pickles_uk_90.fits
# pickles_uk_28 :
# pickles_uk_28.fits
# pickles_uk_128 :
# pickles_uk_128.fits
# pickles_uk_49 :
# pickles_uk_49.fits
# pickles_uk_104 :
# pickles_uk_104.fits
# pickles_uk_32 :
# pickles_uk_32.fits
# pickles_uk_65 :
# pickles_uk_65.fits
# pickles_uk_73 :
# pickles_uk_73.fits
# pickles_uk_112 :
# pickles_uk_112.fits
# pickles_uk_24 :
# pickles_uk_24.fits
# pickles_uk_113 :
# pickles_uk_113.fits
# pickles_uk_25 :
# pickles_uk_25.fits
# pickles_uk_72 :
# pickles_uk_72.fits
# pickles_uk_64 :
# pickles_uk_64.fits
# pickles_uk_105 :
# pickles_uk_105.fits
# pickles_uk_33 :
# pickles_uk_33.fits
# pickles_uk_48 :
# pickles_uk_48.fits
# pickles_uk_129 :
# pickles_uk_129.fits
# pickles_uk_29 :
# pickles_uk_29.fits
# pickles_uk_91 :
# pickles_uk_91.fits
# pickles_uk_87 :
# pickles_uk_87.fits
# pickles_uk_68 :
# pickles_uk_68.fits
# pickles_uk_109 :
# pickles_uk_109.fits
# pickles_uk_44 :
# pickles_uk_44.fits
# pickles_uk_7 :
# pickles_uk_7.fits
# pickles_uk_13 :
# pickles_uk_13.fits
# pickles_uk_125 :
# pickles_uk_125.fits
# pickles_uk_52 :
# pickles_uk_52.fits
# pickles_uk_59 :
# pickles_uk_59.fits
# pickles_uk_18 :
# pickles_uk_18.fits
# pickles_uk_102 :
# pickles_uk_102.fits
# pickles_uk_34 :
# pickles_uk_34.fits
# pickles_uk_63 :
# pickles_uk_63.fits
# pickles_uk_75 :
# pickles_uk_75.fits
# pickles_uk_114 :
# pickles_uk_114.fits
# pickles_uk_22 :
# pickles_uk_22.fits
# pickles_uk_55 :
# pickles_uk_55.fits
# pickles_uk_14 :
# pickles_uk_14.fits
# pickles_uk_122 :
# pickles_uk_122.fits
# pickles_uk_43 :
# pickles_uk_43.fits
# pickles_uk_38 :
# pickles_uk_38.fits
# pickles_uk_80 :
# pickles_uk_80.fits
# pickles_uk_96 :
# pickles_uk_96.fits
# pickles_uk_79 :
# pickles_uk_79.fits
# pickles_uk_118 :
# pickles_uk_118.fits
# pickles_uk_119 :
# pickles_uk_119.fits
# pickles_uk_97 :
# pickles_uk_97.fits
# pickles_uk_78 :
# pickles_uk_78.fits
# pickles_uk_81 :
# pickles_uk_81.fits
# pickles_uk_39 :
# pickles_uk_39.fits
# pickles_uk_42 :
# pickles_uk_42.fits
# pickles_uk_1 :
# pickles_uk_1.fits
# pickles_uk_15 :
# pickles_uk_15.fits
# pickles_uk_123 :
# pickles_uk_123.fits
# pickles_uk_54 :
# pickles_uk_54.fits
# pickles_uk_115 :
# pickles_uk_115.fits
# pickles_uk_23 :
# pickles_uk_23.fits
# pickles_uk_74 :
# pickles_uk_74.fits
# pickles_uk_62 :
# pickles_uk_62.fits
# pickles_uk_103 :
# pickles_uk_103.fits
# pickles_uk_35 :
# pickles_uk_35.fits
# pickles_uk_19 :
# pickles_uk_19.fits
# pickles_uk_58 :
# pickles_uk_58.fits
# pickles_uk_20 :
# pickles_uk_20.fits
# pickles_uk_116 :
# pickles_uk_116.fits
# pickles_uk_77 :
# pickles_uk_77.fits
# pickles_uk_98 :
# pickles_uk_98.fits
# pickles_uk_61 :
# pickles_uk_61.fits
# pickles_uk_36 :
# pickles_uk_36.fits
# pickles_uk_100 :
# pickles_uk_100.fits
# pickles_uk_94 :
# pickles_uk_94.fits
# pickles_uk_82 :
# pickles_uk_82.fits
# pickles_uk_41 :
# pickles_uk_41.fits
# pickles_uk_2 :
# pickles_uk_2.fits
# pickles_uk_120 :
# pickles_uk_120.fits
# pickles_uk_16 :
# pickles_uk_16.fits
# pickles_uk_57 :
# pickles_uk_57.fits
# pickles_uk_56 :
# pickles_uk_56.fits
# pickles_uk_121 :
# pickles_uk_121.fits
# pickles_uk_17 :
# pickles_uk_17.fits
# pickles_uk_3 :
# pickles_uk_3.fits
# pickles_uk_40 :
# pickles_uk_40.fits
# pickles_uk_83 :
# pickles_uk_83.fits
# pickles_uk_95 :
# pickles_uk_95.fits
# pickles_uk_37 :
# pickles_uk_37.fits
# pickles_uk_101 :
# pickles_uk_101.fits
# pickles_uk_60 :
# pickles_uk_60.fits
# pickles_uk_76 :
# pickles_uk_76.fits
# pickles_uk_99 :
# pickles_uk_99.fits
# pickles_uk_21 :
# pickles_uk_21.fits
# pickles_uk_117 :
# pickles_uk_117.fits
# pickles_uk_92 :
# pickles_uk_92.fits
# pickles_uk_84 :
# pickles_uk_84.fits
# pickles_uk_47 :
# pickles_uk_47.fits
# pickles_uk_4 :
# pickles_uk_4.fits
# pickles_uk_126 :
# pickles_uk_126.fits
# pickles_uk_10 :
# pickles_uk_10.fits
# pickles_uk_130 :
# pickles_uk_130.fits
# pickles_uk_51 :
# pickles_uk_51.fits
# pickles_uk_26 :
# pickles_uk_26.fits
# pickles_uk_110 :
# pickles_uk_110.fits
# pickles_uk_71 :
# pickles_uk_71.fits
# pickles_uk_67 :
# pickles_uk_67.fits
# pickles_uk_88 :
# pickles_uk_88.fits
# pickles_uk_30 :
# pickles_uk_30.fits
# pickles_uk_106 :
# pickles_uk_106.fits
# pickles_uk_8 :
# pickles_uk_8.fits
# pickles_uk_9 :
# pickles_uk_9.fits
# pickles_uk_31 :
# pickles_uk_31.fits
# pickles_uk_107 :
# pickles_uk_107.fits
# pickles_uk_66 :
# pickles_uk_66.fits
# pickles_uk_89 :
# pickles_uk_89.fits
# pickles_uk_70 :
# pickles_uk_70.fits
# pickles_uk_27 :
# pickles_uk_27.fits
# pickles_uk_111 :
# pickles_uk_111.fits
# pickles_uk_50 :
# pickles_uk_50.fits
# pickles_uk_131 :
# pickles_uk_131.fits
# pickles_uk_127 :
# pickles_uk_127.fits
# pickles_uk_11 :
# pickles_uk_11.fits
# pickles_uk_5 :
# pickles_uk_5.fits
# pickles_uk_46 :
# pickles_uk_46.fits
# pickles_uk_85 :
# pickles_uk_85.fits
# pickles_uk_93 :
# pickles_uk_93.fits

# %% [markdown]
# ## Plot the SED

# %%
for keyobj in OBJDict:
    the_file=OBJDict[keyobj]
        
    selected_file=the_file
    selected_fullfile=os.path.join(SEDfile_dir,selected_file)
        
    sed=S.FileSpectrum(selected_fullfile)
        
    plt.semilogy(sed.wave,sed.flux,label=keyobj)
    plt.xlim(0, 12000)
    #plt.ylim(1e-23, 1e-6)
    plt.xlabel(sed.waveunits)
    plt.ylabel(sed.fluxunits)
    plt.grid(True)
    #plt.legend(loc='best')
#    plt.title(os.path.basename(S.Vega.name))
    plt.title("pickles uvk models")
    plt.savefig("pickles-uvk.png")
