# %% [markdown]
# # The purpose is to show the BC95

# %% [markdown]
# ## Definitions of the libraries

# %%
import numpy as np
# Set up matplotlib and use a nicer set of plot parameters
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import astropy
from astropy.io import fits
from astropy.coordinates import SkyCoord, EarthLocation, AltAz

# %%
import pandas as pd
import os
import re

# %%
from astroquery.simbad import Simbad

# %%
# to enlarge the sizes
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 8),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
top_pysynphot_data_dir=os.environ['PYSYN_CDBS']

# %%
import pysynphot as S
S.primary_area=6*1e4
S.binning=10.

# %% [markdown]
# ## Defines where are the data

# %%
dir_star='calspec'
dir_nostar='grid'

# %%
dir_submodels=['agn','bpgs','extinction','jacobi','phoenix','bc95','bz77','galactic','k93models','pickles','bkmodels','ck04models','gunnstryker','kc96']

# %% [markdown]
# ## where are the files

# %%
SEDfile_dir=os.path.join(top_pysynphot_data_dir,dir_nostar,dir_submodels[5],'templates')

# %%
filelist=os.listdir(SEDfile_dir)

# %%
fits_files = [f for f in os.listdir(SEDfile_dir) if f.endswith('.fits')]

# %% [markdown]
# ## Find the star-names in the files

# %%
obj_headers = []
obj_files = []
for filename in filelist:
    index=0
    if re.search('fits',filename):  #example of filename filter
        index+=1
        fullfilename = os.path.join(SEDfile_dir,filename)
        hdr = fits.getheader(fullfilename)
        obj_headers.append(hdr)
        obj_files.append(filename)

# %%
obj_names = []
index=0
for hdr in obj_headers: 
        obj_name=obj_headers[index]['TARGETID']
        obj_names.append(obj_name)
        index+=1

# %%
print obj_names
# Out:
# ['bc95_a', 'bc95_a', 'bc95_a', 'bc95_a', 'bc95_a', 'bc95_a', 'bc95_a', 'bc95_a', 'bc95_a', 'bc95_a', 'bc95_a', 'bc95_a', 'bc95_b', 'bc95_b', 'bc95_b', 'bc95_b', 'bc95_b', 'bc95_b', 'bc95_b', 'bc95_b', 'bc95_b', 'bc95_b', 'bc95_b', 'bc95_b', 'bc95_c', 'bc95_c', 'bc95_c', 'bc95_c', 'bc95_c', 'bc95_c', 'bc95_c', 'bc95_c', 'bc95_c', 'bc95_c', 'bc95_c', 'bc95_c', 'bc95_d', 'bc95_d', 'bc95_d', 'bc95_d', 'bc95_d', 'bc95_d', 'bc95_d', 'bc95_d', 'bc95_d', 'bc95_d', 'bc95_d', 'bc95_d', 'bc95_e', 'bc95_e', 'bc95_e', 'bc95_e', 'bc95_e', 'bc95_e', 'bc95_e', 'bc95_e', 'bc95_e', 'bc95_e', 'bc95_e', 'bc95_e', 'bc95_f', 'bc95_f', 'bc95_f', 'bc95_f', 'bc95_f', 'bc95_f', 'bc95_f', 'bc95_f', 'bc95_f', 'bc95_f', 'bc95_f', 'bc95_f', 'bc95_g', 'bc95_g', 'bc95_g', 'bc95_g', 'bc95_g', 'bc95_g', 'bc95_g', 'bc95_g', 'bc95_g', 'bc95_g', 'bc95_g', 'bc95_g']

# %%
print obj_files
# Out:
# ['bc95_a_10E5.fits', 'bc95_a_10E6.fits', 'bc95_a_10E7.fits', 'bc95_a_10E8.fits', 'bc95_a_10E9.fits', 'bc95_a_25E5.fits', 'bc95_a_25E6.fits', 'bc95_a_50E5.fits', 'bc95_a_50E6.fits', 'bc95_a_50E7.fits', 'bc95_a_50E8.fits', 'bc95_a_76E5.fits', 'bc95_b_10E5.fits', 'bc95_b_10E6.fits', 'bc95_b_10E7.fits', 'bc95_b_10E8.fits', 'bc95_b_10E9.fits', 'bc95_b_25E5.fits', 'bc95_b_25E6.fits', 'bc95_b_50E5.fits', 'bc95_b_50E6.fits', 'bc95_b_50E7.fits', 'bc95_b_50E8.fits', 'bc95_b_76E5.fits', 'bc95_c_10E5.fits', 'bc95_c_10E6.fits', 'bc95_c_10E7.fits', 'bc95_c_10E8.fits', 'bc95_c_10E9.fits', 'bc95_c_25E5.fits', 'bc95_c_25E6.fits', 'bc95_c_50E5.fits', 'bc95_c_50E6.fits', 'bc95_c_50E7.fits', 'bc95_c_50E8.fits', 'bc95_c_76E5.fits', 'bc95_d_10E5.fits', 'bc95_d_10E6.fits', 'bc95_d_10E7.fits', 'bc95_d_10E8.fits', 'bc95_d_10E9.fits', 'bc95_d_25E5.fits', 'bc95_d_25E6.fits', 'bc95_d_50E5.fits', 'bc95_d_50E6.fits', 'bc95_d_50E7.fits', 'bc95_d_50E8.fits', 'bc95_d_76E5.fits', 'bc95_e_10E5.fits', 'bc95_e_10E6.fits', 'bc95_e_10E7.fits', 'bc95_e_10E8.fits', 'bc95_e_10E9.fits', 'bc95_e_25E5.fits', 'bc95_e_25E6.fits', 'bc95_e_50E5.fits', 'bc95_e_50E6.fits', 'bc95_e_50E7.fits', 'bc95_e_50E8.fits', 'bc95_e_76E5.fits', 'bc95_f_10E5.fits', 'bc95_f_10E6.fits', 'bc95_f_10E7.fits', 'bc95_f_10E8.fits', 'bc95_f_10E9.fits', 'bc95_f_25E5.fits', 'bc95_f_25E6.fits', 'bc95_f_50E5.fits', 'bc95_f_50E6.fits', 'bc95_f_50E7.fits', 'bc95_f_50E8.fits', 'bc95_f_76E5.fits', 'bc95_g_10E5.fits', 'bc95_g_10E6.fits', 'bc95_g_10E7.fits', 'bc95_g_10E8.fits', 'bc95_g_10E9.fits', 'bc95_g_25E5.fits', 'bc95_g_25E6.fits', 'bc95_g_50E5.fits', 'bc95_g_50E6.fits', 'bc95_g_50E7.fits', 'bc95_g_50E8.fits', 'bc95_g_76E5.fits']

# %%
objames_and_objfiles = zip(obj_names, obj_files)

# %% [markdown]
# ## Make a dictionary of filenames

# bc95_e_10E8.fits
# bc95_e 52 :
# bc95_e_10E9.fits
# bc95_e 53 :
# bc95_e_25E5.fits
# bc95_e 54 :
# bc95_e_25E6.fits
# bc95_e 55 :
# bc95_e_50E5.fits
# bc95_e 56 :
# bc95_e_50E6.fits
# bc95_e 57 :
# bc95_e_50E7.fits
# bc95_e 58 :
# bc95_e_50E8.fits
# bc95_e 59 :
# bc95_e_76E5.fits
# bc95_f 60 :
# bc95_f_10E5.fits
# bc95_f 61 :
# bc95_f_10E6.fits
# bc95_f 62 :
# bc95_f_10E7.fits
# bc95_f 63 :
# bc95_f_10E8.fits
# bc95_f 64 :
# bc95_f_10E9.fits
# bc95_f 65 :
# bc95_f_25E5.fits
# bc95_f 66 :
# bc95_f_25E6.fits
# bc95_f 67 :
# bc95_f_50E5.fits
# bc95_f 68 :
# bc95_f_50E6.fits
# bc95_f 69 :
# bc95_f_50E7.fits
# bc95_f 70 :
# bc95_f_50E8.fits
# bc95_f 71 :
# bc95_f_76E5.fits
# bc95_g 72 :
# bc95_g_10E5.fits
# bc95_g 73 :
# bc95_g_10E6.fits
# bc95_g 74 :
# bc95_g_10E7.fits
# bc95_g 75 :
# bc95_g_10E8.fits
# bc95_g 76 :
# bc95_g_10E9.fits
# bc95_g 77 :
# bc95_g_25E5.fits
# bc95_g 78 :
# bc95_g_25E6.fits
# bc95_g 79 :
# bc95_g_50E5.fits
# bc95_g 80 :
# bc95_g_50E6.fits
# bc95_g 81 :
# bc95_g_50E7.fits
# bc95_g 82 :
# bc95_g_50E8.fits
# bc95_g 83 :
# bc95_g_76E5.fits

# %%
OBJDict
# Out:
# {'bc95_a': 'bc95_a_76E5.fits',
#  'bc95_b': 'bc95_b_76E5.fits',
#  'bc95_c': 'bc95_c_76E5.fits',
#  'bc95_d': 'bc95_d_76E5.fits',
#  'bc95_e': 'bc95_e_76E5.fits',
#  'bc95_f': 'bc95_f_76E5.fits',
#  'bc95_g': 'bc95_g_76E5.fits'}

# %% [markdown]
# ## Plot the SED

# %%
all_sed=[]
#for keyobj in OBJDict:
for obj,thefile in objames_and_objfiles:
    keyobj=obj
    #the_file=OBJDict[keyobj]
        
    #selected_file=the_file
    selected_file=thefile
    selected_fullfile=os.path.join(SEDfile_dir,selected_file)
        
    sed=S.FileSpectrum(selected_fullfile)
     
    all_sed.append(sed)    
    plt.semilogy(sed.wave,sed.flux,label=keyobj)
    plt.xlim(0, 12000)
    #plt.ylim(1e-23, 1e-6)
    plt.xlabel(sed.waveunits)
    plt.ylabel(sed.fluxunits)
    plt.grid(True)
    plt.legend(loc='best')
#    plt.title(os.path.basename(S.Vega.name))
    plt.title("BC95 templates")
    plt.savefig("bc95.png")

# %%
print len(all_sed)
